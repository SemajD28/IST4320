# %%
#Question 1a : Given a list of cities and their corresponding ZIP codes, extract the ZIP codes and organize them into a tuple. 

zipcode = {'90210':'Beverly Hills, CA', '60601': 'Chicago, IL', '94102':'San Francisco, CA'}
 
zip_codes_tuple = tuple(zipcode.keys())

print("ZIP codes tuple:", zip_codes_tuple) 
    
    
#Question 1b: Rearrange the tuple in reverse order from 1a. 

# Given tuple from question 1a
zip_codes_tuple = ('90210', '60601', '94102')

# Rearrange the tuple in reverse order
reversed_zip_codes_tuple = zip_codes_tuple[::-1]

print("Reversed ZIP codes tuple:", reversed_zip_codes_tuple)
# Out:
# ZIP codes tuple: ('90210', '60601', '94102')
# Reversed ZIP codes tuple: ('94102', '60601', '90210')

# %%
# question 2 : Here is a list of groceries. The user needs help extracting the text "apples" and placing the text "apples" into the sentence below.
#  Please use regular expressions. ( regex ) 
import re

random_text = "Milk, eggs, bread, butter, cheese, fresh fruits (e.g., apples, bananas), fresh vegetables (e.g., lettuce, tomatoes), rice, pasta, canned tomatoes, chicken breasts or thighs, ground beef or turkey, cooking oil (e.g., olive oil), spices (e.g., salt, pepper), snacks (e.g., chips, nuts)"

# Use regular expression to find "apples"
match = re.search(r'\bapples\b', random_text)

if match:
    # Extract the matched text
    apples_text = match.group(0)
    
    # Sentence to insert "apples"
    new_sentence = "I need to buy {} today.".format(apples_text)

    print(new_sentence)
else:
    print("The text 'apples' was not found in the given sentence.")

#What is the starting and ending position of the text "apples" in random_text? Paste below 👇 
import re

random_text = "Milk, eggs, bread, butter, cheese, fresh fruits (e.g., apples, bananas), fresh vegetables (e.g., lettuce, tomatoes), rice, pasta, canned tomatoes, chicken breasts or thighs, ground beef or turkey, cooking oil (e.g., olive oil), spices (e.g., salt, pepper), snacks (e.g., chips, nuts)"

# Use regular expression to find "apples"
match = re.search(r'\bapples\b', random_text)

if match:
    # Get starting and ending positions of the match
    start_position = match.start()
    end_position = match.end()

    print("Starting position:", start_position)
    print("Ending position:", end_position)
else:
    print("The text 'apples' was not found in the given sentence.")
# Out:
# I need to buy apples today.
# Starting position: 55
# Ending position: 61

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# URL of the website
site = "https://littlespoonfarm.com/apple-pie-recipe/"

# Fetch the HTML content of the website
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site, headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page, 'html.parser')

# Find all 'ul' and 'ol' elements containing the recipe ingredients
ingredient_lists = soup.find_all(['ul', 'ol'])

# Extract the text content of each ingredient list
recipe_ingredients = []
for ingredient_list in ingredient_lists:
    ingredients = ingredient_list.find_all('li')
    for ingredient in ingredients:
        recipe_ingredients.append(ingredient.text.strip())

# Print the recipe ingredients
print("Recipe Ingredients:")
for ingredient in recipe_ingredients:
    print(ingredient)
# Out:
# Recipe Ingredients:
# Home
# About
# Membership
# Sign in
# All Recipes
# Sourdough
# Discard
#
# Home
# Membership
# All Recipes
# Sourdough
# Discard
# About
# Contact
# Sign in
#
#
# pie crust
# apples
# granulated sugar
# brown sugar
# flour
# cinnamon
# nutmeg
# lemon
# egg
# 9" pie plate
# rolling pin
# parchment paper
# whisk
# spatula
# pie weights or dried beans
# pie shield or foil
# mixing bowls
# measuring cups and spoons
# Granny Smith - These are the best apples for making apple pie because they are super tart and very firm. Firm apples hold up well during the baking process unlike varieties such as McIntosh which kind of turn to mush.
# Honeycrisp - This is my second choice when it comes to apple pie. This variety is super crisp, tart, sweet and holds up great during the baking process.
# Jazz - Another crisp and sweet apple variety.
# Golden Delicious - Widely available apple variety. Holds up well during the baking process but will be a little softer than the others.
# Jonagold - A little tart and sweet.
# Pink Lady - Just like Jonagolds, this variety has a good balance of tart and sweet.
# oreo cheesecake
# chocolate chip cookies
# old fashioned peanut butter pie
# banana pudding
# 2 (9")   pie crusts
# 7 large   Granny Smith apples (peeled, cored and sliced into ½ inch slices)
# ½ cup   granulated sugar
# ½ cup   light brown sugar (loosely packed)
# 2 tablespoons   all-purpose flour
# 1 teaspoon   ground cinnamon
# ⅛ teaspoon   ground nutmeg
# 1 tablespoon   lemon juice (plus the zest of half of a lemon)
# 1 large   egg (lightly beaten in a small bowl for egg wash)
# 2 tablespoons   sanding sugar (optional)
# Start by preparing this flaky pie crust recipe which makes 2 (9") pie crusts, one for the bottom and one for the top of the pie. The pie dough will need to chill for at least 1 hour before rolling out. Or use a store-bought pie crust and follow package directions.
# Place oven rack in the center position and Preheat the oven to 400°F (204°C).
# In a large bowl, combine the sliced apples, granulated sugar, light brown sugar, flour, cinnamon,  nutmeg,  and lemon juice and lemon zest; toss to coat evenly.
# Remove the pie crust dough from the fridge and let rest at room temperature for 5-10 minutes. On a lightly floured surface, roll one disc into a 12" circle that is ⅛" thick. Carefully lay the crust into the bottom of a deep dish pie plate.
# Spoon the apple filling over the bottom crust and discard juices at the bottom of the bowl. Roll out the second disc of pie crust until it is ⅛" thick and lay it over the apple filling.
# Use a sharp knife to trim the dough along the outside edge of the pie plate. Lift the edges where the two pie crust meet, gently press to seal and fold them under. Rotate the pie plate and repeat this process until edges are neatly tucked under themselves. Cut 4 slits in the top of the dough to allow steam to vent. Place the pie on a baking sheet.
# Brush the surface of the pie crust with the egg wash and sprinkle with sanding sugar. Cover the edges with a pie shield or a strip of foil to keep them from over browning during the first 25 minutes.
# Bake at 400°F (204°C) for 25 minutes. Carefully remove the pie shield, turn the oven down to 375° and continue to bake for an additional 30-35 minutes or until the top is golden brown and the juices are bubbly. Cool at room temperature for at least 3 hours.
# Karin says
# March 25, 2024 at 8:55 pm
#
#
# Thanks for this great and simple recipe!  I stopped using processed sugars years ago, so replaced granulated sugar and brown sugar with 2/3 cup honey, and added an extra tablespoon flour to counter the extra moisture.
#
# Reply
# Cristina Kub says
# March 19, 2024 at 2:58 pm
#
#
# This recipe is the very best apple pie recipe I ever made let alone the easiest. I am old so I have made many over the years. I am so happy I found this one and will always make this recipe for my family when they are in the mood for pie. Many thanks to Amy Duska for this recipe!
#
# Reply
# Katherine says
# March 14, 2024 at 7:25 pm
#
#
# great recipe awesome thanks 😊❤️ so much
#
# Reply
# Facebook
# Instagram
# Pinterest
# YouTube
# About
# Contact
# Sign in
# Sourdough
# Discard
# Dessert

# %%
# question 4 :
# Here are two sets 
#4a: Create a code for the user who wants to extract only even numbers from setA.
setA = {-82, 45, -27, 69, -14, 83, 57, -91, 36, -3, 18, -60, 74, -38, 5, -70, 29, 91, -52, 12, -46, 63, -9, 42, 77, -65, 21, -37, 88, -20}
# Extract even numbers from setA
even_numbers = {num for num in setA if num % 2 == 0}

print("Even numbers from setA:", even_numbers)


#4b: Create a code for the user who wants to extract only odd numbers from setB.
setB = {-88, 17, -42, 69, -31, 58, 74, -95, 25, -13, 36, -67, 82, -50, 41, -73, 6, 91, -29, 52, -84, 27, -20, 63, 79, -58, 12, -35, 88, -16}
# Extract odd numbers from setB
odd_numbers = {num for num in setB if num % 2 != 0}

print("Odd numbers from setB:", odd_numbers)    


      
#4c: Find the intersection between set2 and set3.

set2 = {1,2,4,5,6,7,8,9}
set3 = {2,9,5,6,15,13}

intersection_set = set2 & set3

print("Intersection between set2 and set3:", intersection_set)
# Out:
# Even numbers from setA: {-70, -60, 36, 74, 42, -52, 12, -20, -82, 18, -46, -14, 88, -38}
# Odd numbers from setB: {-95, -31, -29, 69, 41, 91, 79, -67, 17, -13, -73, 25, 27, -35, 63}
# Intersection between set2 and set3: {9, 2, 5, 6}

# %%
# Question 5
#Upload your completed lab to your GitHub and submit the link to yout Git Hub account.
